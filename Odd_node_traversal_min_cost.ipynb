# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
#Cleaning the input graph for traversal
def graph_clean(g1,strt,end):
    list=[]
    for i in g1.nodes:
     if (i%2==0 and i!=strt and i!=dest):
        list.append(i)
     #print(list)
    return(list)
   # remove_items(g1,list)

# %%
def shortest_path_odd_node_traversal(start,finish):
    return(nx.dijkstra_path(g1,start,finish),nx.dijkstra_path_length(g1,strt,finish))

# %%
g1=g=nx.Graph()

# %%
g1.add_weighted_edges_from([[7,17,10],[15,17,4],[0,1,5],[0,2,1],[0,4,2],[1,13,4],[1,3,2],[3,13,3],[2,3,3],[3,6,1],[4,5,3],[6,5,1],[5,7,2],[5,10,5],[6,7,7],[8,9,2],[7,10,5],[10,16,3],[6,9,1],[3,9,1],[3,11,1],[11,12,7],[11,9,3],[9,7,4],[8,7,5],[12,8,2],[8,14,5],[14,15,3],[8,17,5],[16,17,2],[17,18,1],[16,19,10]])

# %%
#g1.add_weighted_edges_from([[0,1,5],[0,2,4],[0,3,2],[0,4,7],[1,2,7],[1,3,4],[1,4,3],[2,3,5],[2,4,6],[3,4,8]])

# %%
nx.draw_networkx(g1)

# %%
v1,v2=input("Enter the start and end vertices(separated by space) for Traversal ").split()
# Out:
# Enter the start and end vertices(separated by space) for Traversal 5 12

# %%
strt=int(v1)
dest=int(v2)

# %%
list1=graph_clean(g1,strt,dest)
for j in list1:
    g1.remove_node(j)
print("Remaining Nodes",g1.nodes)
print("updated Graph After Cleaning\n",nx.draw_networkx(g1))
# Out:
# Remaining Nodes [7, 17, 15, 1, 13, 3, 5, 9, 11, 12, 19]
# updated Graph After Cleaning
#  None

# %%
shortest_path=[]
try:
    shortest_path,cost=shortest_path_odd_node_traversal(strt,dest)
    print("Shortest path between {} and {} by odd-node traversal :\n".format(strt,dest),shortest_path)
    print("Cost of Traversal:",cost)
except nx.NetworkXNoPath:
    print("No path found between {} and {}".format(strt,dest))
# Out:
# Shortest path between 5 and 12 by odd-node traversal :
#  [5, 7, 9, 3, 11, 12]
# Cost of Traversal: 15

# %%
#g.adj[1][13]  #syntax--> graph_object.adj[node_name][neighbour_name]

# %%
#g.adj.items()

# %%
#g[1].items()

# %%
#nx.draw_networkx(g1)

# %%
#g1.nodes
