# %%
import pandas as pd

# %%
df=pd.read_csv("nba_america.csv")

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
pd.crosstab(df.Name,df.Position)
# Out:
# Position             C  PF  PG  SF  SG
# Name
# Aaron Brooks         0   0   1   0   0
# Aaron Gordon         0   1   0   0   0
# Aaron Harrison       0   0   0   0   1
# Adreian Payne        0   1   0   0   0
# Al Horford           1   0   0   0   0
# Al Jefferson         1   0   0   0   0
# Al-Farouq Aminu      0   0   0   1   0
# Alan Anderson        0   0   0   0   1
# Alan Williams        1   0   0   0   0
# Alec Burks           0   0   0   0   1
# Alex Len             1   0   0   0   0
# Alex Stepheson       0   1   0   0   0
# Alexis Ajinca        1   0   0   0   0
# Allen Crabbe         0   0   0   0   1
# Alonzo Gee           0   0   0   1   0
# Amar'e Stoudemire    0   1   0   0   0
# Amir Johnson         0   1   0   0   0
# Anderson Varejao     0   1   0   0   0
# Andre Drummond       1   0   0   0   0
# Andre Iguodala       0   0   0   1   0
# Andre Miller         0   0   1   0   0
# Andre Roberson       0   0   0   0   1
# Andrew Bogut         1   0   0   0   0
# ...

# %%
pd.crosstab(df.Team,df.College)
# Out:
# College                 Alabama  Arizona  Arizona State  Arkansas  Baylor  \
# Team
# Atlanta Hawks                 0        0              0         0       0
# Boston Celtics                0        0              0         0       0
# Brooklyn Nets                 0        1              0         0       0
# Charlotte Hornets             0        0              0         0       0
# Chicago Bulls                 0        0              0         1       0
# Cleveland Cavaliers           1        2              0         0       0
# Dallas Mavericks              0        0              0         0       0
# Denver Nuggets                0        0              0         0       0
# Detroit Pistons               0        1              0         0       0
# Golden State Warriors         0        1              0         0       0
# Houston Rockets               0        1              1         1       0
# Indiana Pacers                0        2              0         0       0
# ...

# %%
pd.crosstab(df.College,df.Salary)
# Out:
# Salary                 55722.0     83397.0     111196.0    111444.0    \
# College
# Alabama                         0           0           0           0
# Arizona                         0           0           0           0
# Arizona State                   0           0           0           1
# Arkansas                        0           0           0           0
# Baylor                          0           0           0           0
# Belmont                         0           0           0           0
# Blinn College                   0           0           0           0
# Boston College                  0           0           0           0
# Bowling Green                   0           0           0           0
# Bucknell                        0           0           0           0
# Butler                          0           0           0           0
# California                      0           0           0           0
# ...
